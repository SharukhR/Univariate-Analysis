# %%
import pandas as pd

# %%
dataset= pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 0     Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2    Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3     Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4    Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
# ..         ...    ...      ...            ...    ...         ...       ...
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed  204000.0
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       NaN
#
# [215 rows x 15 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
#quan= [" ssc_p ","hsc_p","degree_p","etest_p","mba_p","salary"]
#qual= ["gender","ssc_b","hsc_b","hsc_s","degree_t","workex","specialisation","status"]

# %%
dataset.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
dataset["gender"].dtypes
# Out:
# dtype('O')

# %%
quan=[]
qual=[]
for columnName in dataset.columns:
    print(columnName)
    if (dataset[columnName].dtypes=='O'):
        #print ("qual")
        qual.append(columnName)
    else:
        #print ("quan")
        quan.append(columnName)
# Out:
# sl_no
# gender
# ssc_p
# ssc_b
# hsc_p
# hsc_b
# hsc_s
# degree_p
# degree_t
# workex
# etest_p
# specialisation
# mba_p
# status
# salary

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
def quanqual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        if (dataset[columnName].dtypes=='O'):
            #print ("qual")
            qual.append(columnName)
        else:
            #print ("quan")
            quan.append(columnName)
    return quan,qual

# %%
quanqual(dataset)
# Out:
# (['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'],
#  ['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'])

# %% [markdown]
# # Central tendency

# %%
dataset["ssc_p"].mean()
# Out:
# np.float64(67.30339534883721)

# %%
dataset["ssc_p"].median()
# Out:
# 67.0

# %%
dataset["ssc_p"].mode()[0]
# Out:
# np.float64(62.0)

# %%
dataset.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
descriptive=pd.DataFrame()

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)

# %%
descriptive["hsc_p"]["Median"]=0
# Out:
# C:\Users\sharu\AppData\Local\Temp\ipykernel_19936\2333899791.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive["hsc_p"]["Median"]=0

# %%
descriptive = pd.DataFrame(index=["Mean", "Median", "Mode"], columns=quan)

for columnName in quan:
    descriptive.loc["Mean", columnName] = dataset[columnName].mean()
    descriptive.loc["Median", columnName] = dataset[columnName].median()
    descriptive.loc["Mode", columnName] = dataset[columnName].mode()[0]

# %%
descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median  108.0       67.0       65.0       66.0       71.0       62.0
# Mode        1       62.0       63.0       65.0       60.0       56.7
#
#                salary
# Mean    288655.405405
# Median       265000.0
# Mode         300000.0

# %%
import numpy as np

# %%
float(np.percentile(dataset["ssc_p"],50))
# Out:
# 67.0

# %%
descriptive = pd.DataFrame(index=["Mean", "Median", "Mode","Q1:25%","Q2:50%","Q3:75%","Q4:100%","IQR","1.5rule","Lesser","Greater","Min","Max"], columns=quan)

for columnName in quan:
    descriptive.loc["Mean", columnName] = dataset[columnName].mean()
    descriptive.loc["Median", columnName] = dataset[columnName].median()
    descriptive.loc["Mode", columnName] = dataset[columnName].mode()[0]
    descriptive.loc["Q1:25%", columnName] = dataset.describe()[columnName]["25%"]
    descriptive.loc["Q2:50%", columnName] = dataset.describe()[columnName]["50%"]
    descriptive.loc["Q3:75%", columnName] = dataset.describe()[columnName]["75%"]
    descriptive.loc["Q4:100%", columnName] = dataset.describe()[columnName]["max"]
    descriptive.loc["IQR", columnName] = (descriptive.loc["Q3:75%", columnName] - descriptive.loc["Q1:25%", columnName])
    descriptive.loc["1.5rule", columnName] = 1.5 *descriptive.loc["IQR", columnName]
    descriptive.loc["Lesser", columnName] =  descriptive.loc["Q1:25%", columnName]-descriptive.loc["1.5rule", columnName]
    descriptive.loc["Greater", columnName] =  descriptive.loc["Q3:75%", columnName]+descriptive.loc["1.5rule", columnName]
    descriptive.loc["Min", columnName] =dataset[columnName].min()
    descriptive.loc["Max", columnName] =dataset[columnName].max()

# %%
descriptive
# Out:
#          sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean     108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median   108.0       67.0       65.0       66.0       71.0       62.0
# Mode         1       62.0       63.0       65.0       60.0       56.7
# Q1:25%    54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%   108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%   161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%  215.0       89.4       97.7       91.0       98.0      77.89
# IQR      107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule  160.5      22.65      18.15       16.5      35.25     12.465
# Lesser  -106.0      37.95      42.75       44.5      24.75      45.48
# Greater  322.0      98.35      91.15       88.5     118.75      78.72
# Min          1      40.89       37.0       50.0       50.0      51.21
# Max        215       89.4       97.7       91.0       98.0      77.89
#
#                 salary
# Mean     288655.405405
# Median        265000.0
# Mode          300000.0
# Q1:25%        240000.0
# Q2:50%        265000.0
# Q3:75%        300000.0
# Q4:100%       940000.0
# IQR            60000.0
# 1.5rule        90000.0
# Lesser        150000.0
# Greater       390000.0
# Min           200000.0
# Max           940000.0

# %%
bool(descriptive.loc["Min"]["hsc_p"]<descriptive.loc["Lesser"]["hsc_p"])
# Out:
# True

# %%
lesser=[]
greater=[]

for columnName in quan:
    if (bool(descriptive.loc["Min"][columnName]<descriptive.loc["Lesser"][columnName])):
        lesser.append(columnName)
    if (bool(descriptive.loc["Max"][columnName]>descriptive.loc["Greater"][columnName])):
        greater.append(columnName)

# %%
lesser
# Out:
# ['hsc_p']

# %%
greater
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %%
for columnName in lesser + greater:
    lower = descriptive.loc["Lesser", columnName]
    upper = descriptive.loc["Greater", columnName]
    
    # Replace lower outliers
    dataset.loc[dataset[columnName] < lower, columnName] = lower
    
    # Replace upper outliers
    dataset.loc[dataset[columnName] > upper, columnName] = upper

# %%
for columnName in lesser + greater:
    lower = descriptive.loc["Lesser", columnName]
    upper = descriptive.loc["Greater", columnName]
    below = (dataset[columnName] < lower).sum()
    above = (dataset[columnName] > upper).sum()
    print(f"{columnName}: Below = {below}, Above = {above}")
# Out:
# hsc_p: Below = 0, Above = 0
# hsc_p: Below = 0, Above = 0
# degree_p: Below = 0, Above = 0
# salary: Below = 0, Above = 0

# %%
dataset["ssc_p"].value_counts()
# Out:
# ssc_p
# 62.00    11
# 63.00    10
# 67.00     9
# 73.00     9
# 52.00     9
#          ..
# 55.68     1
# 41.00     1
# 83.33     1
# 43.00     1
# 80.60     1
# Name: count, Length: 103, dtype: int64

# %%
freqTable=pd.DataFrame(columns=["Unique_Values","Freqency","Relative Frequency","Cumsum"])

# %%
freqTable["Unique_Values"]=dataset["ssc_p"].value_counts().index
freqTable["Frequency"]=dataset["ssc_p"].value_counts().values
freqTable["Relative Frequency"]= (freqTable["Frequency"]/103)
freqTable["Cumsum"]= freqTable["Relative Frequency"].cumsum()

# %%
freqTable
# Out:
#      Unique_Values Freqency  Relative Frequency    Cumsum  Frequency
# 0            62.00      NaN            0.106796  0.106796         11
# 1            63.00      NaN            0.097087  0.203883         10
# 2            67.00      NaN            0.087379  0.291262          9
# 3            73.00      NaN            0.087379  0.378641          9
# 4            52.00      NaN            0.087379  0.466019          9
# ..             ...      ...                 ...       ...        ...
# 98           55.68      NaN            0.009709  2.048544          1
# 99           41.00      NaN            0.009709  2.058252          1
# 100          83.33      NaN            0.009709  2.067961          1
# 101          43.00      NaN            0.009709  2.077670          1
# 102          80.60      NaN            0.009709  2.087379          1
#
# [103 rows x 5 columns]

# %%
def freqTable(columnName, dataset):
    freqTable=pd.DataFrame(columns=["Unique_Values","Freqency","Relative Frequency","Cumsum"])
    freqTable["Unique_Values"]=dataset[columnName].value_counts().index
    freqTable["Frequency"]=dataset[columnName].value_counts().values
    freqTable["Relative Frequency"]= (freqTable["Frequency"]/103)
    freqTable["Cumsum"]= freqTable["Relative Frequency"].cumsum()
    return freqTable

# %%
freqTable("hsc_p",dataset)
# Out:
#     Unique_Values Freqency  Relative Frequency    Cumsum  Frequency
# 0           63.00      NaN            0.135922  0.135922         14
# 1           62.00      NaN            0.116505  0.252427         12
# 2           67.00      NaN            0.087379  0.339806          9
# 3           60.00      NaN            0.087379  0.427184          9
# 4           70.00      NaN            0.077670  0.504854          8
# ..            ...      ...                 ...       ...        ...
# 86          65.50      NaN            0.009709  2.048544          1
# 87          77.60      NaN            0.009709  2.058252          1
# 88          70.20      NaN            0.009709  2.067961          1
# 89          61.40      NaN            0.009709  2.077670          1
# 90          61.33      NaN            0.009709  2.087379          1
#
# [91 rows x 5 columns]

# %%
def Univariate(dataset,quan):
    descriptive = pd.DataFrame(index=["Mean", "Median", "Mode","Q1:25%","Q2:50%","Q3:75%","Q4:100%","IQR","1.5rule","Lesser","Greater","Min","Max","skew","kurtosis"], columns=quan)

    for columnName in quan:
        descriptive.loc["Mean", columnName] = dataset[columnName].mean()
        descriptive.loc["Median", columnName] = dataset[columnName].median()
        descriptive.loc["Mode", columnName] = dataset[columnName].mode()[0]
        descriptive.loc["Q1:25%", columnName] = dataset.describe()[columnName]["25%"]
        descriptive.loc["Q2:50%", columnName] = dataset.describe()[columnName]["50%"]
        descriptive.loc["Q3:75%", columnName] = dataset.describe()[columnName]["75%"]
        descriptive.loc["Q4:100%", columnName] = dataset.describe()[columnName]["max"]
        descriptive.loc["IQR", columnName] = (descriptive.loc["Q3:75%", columnName] - descriptive.loc["Q1:25%", columnName])
        descriptive.loc["1.5rule", columnName] = 1.5 *descriptive.loc["IQR", columnName]
        descriptive.loc["Lesser", columnName] =  descriptive.loc["Q1:25%", columnName]-descriptive.loc["1.5rule", columnName]
        descriptive.loc["Greater", columnName] =  descriptive.loc["Q3:75%", columnName]+descriptive.loc["1.5rule", columnName]
        descriptive.loc["Min", columnName] =dataset[columnName].min()
        descriptive.loc["Max", columnName] =dataset[columnName].max()
        descriptive.loc["skew", columnName] =dataset[columnName].skew()
        descriptive.loc["kurtosis", columnName] =dataset[columnName].kurtosis()
    return descriptive

# %%
Univariate(dataset,quan)
# Out:
#           sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean      108.0  67.303395  66.334744  66.358558  72.100558  62.278186
# Median    108.0       67.0       65.0       66.0       71.0       62.0
# Mode          1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%    161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%   215.0       89.4      91.15       88.5       98.0      77.89
# IQR       107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule   160.5      22.65      18.15       16.5      35.25     12.465
# Lesser   -106.0      37.95      42.75       44.5      24.75      45.48
# Greater   322.0      98.35      91.15       88.5     118.75      78.72
# Min           1      40.89      42.75       50.0       50.0      51.21
# Max         215       89.4      91.15       88.5       98.0      77.89
# skew        0.0  -0.132649   0.162611   0.204164   0.282308   0.313576
# kurtosis   -1.2   -0.60751   0.086901   -0.09749   -1.08858  -0.470723
#
#                  salary
# Mean      277648.648649
# Median         265000.0
# Mode           300000.0
# Q1:25%         240000.0
# Q2:50%         265000.0
# Q3:75%         300000.0
# Q4:100%        390000.0
# IQR             60000.0
# 1.5rule         90000.0
# Lesser         150000.0
# Greater        390000.0
# Min            200000.0
# Max            390000.0
# skew             0.8067
# kurtosis      -0.239837

# %%
def check_outlier():
    lesser=[]
    greater=[]
    
    for columnName in quan:
        if (bool(descriptive.loc["Min"][columnName]<descriptive.loc["Lesser"][columnName])):
            lesser.append(columnName)
        if (bool(descriptive.loc["Max"][columnName]>descriptive.loc["Greater"][columnName])):
            greater.append(columnName) 
    return lesser,greater

# %%
def replace_outlier():
    for columnName in lesser + greater:
        lower = descriptive.loc["Lesser", columnName]
        upper = descriptive.loc["Greater", columnName]
        
        # Replace lower outliers
        dataset.loc[dataset[columnName] < lower, columnName] = lower
        
        # Replace upper outliers
        dataset.loc[dataset[columnName] > upper, columnName] = upper
    for columnName in lesser + greater:
        lower = descriptive.loc["Lesser", columnName]
        upper = descriptive.loc["Greater", columnName]
        below = (dataset[columnName] < lower).sum()
        above = (dataset[columnName] > upper).sum()
        print(f"{columnName}: Below = {below}, Above = {above}")

# %%
dataset["ssc_p"].skew()
# Out:
# np.float64(-0.13264949031456927)

# %%
dataset["ssc_p"].kurtosis()
# Out:
# np.float64(-0.6075102066986688)

# %%
Univariate(dataset,quan)
# Out:
#           sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean      108.0  67.303395  66.334744  66.358558  72.100558  62.278186
# Median    108.0       67.0       65.0       66.0       71.0       62.0
# Mode          1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%    161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%   215.0       89.4      91.15       88.5       98.0      77.89
# IQR       107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule   160.5      22.65      18.15       16.5      35.25     12.465
# Lesser   -106.0      37.95      42.75       44.5      24.75      45.48
# Greater   322.0      98.35      91.15       88.5     118.75      78.72
# Min           1      40.89      42.75       50.0       50.0      51.21
# Max         215       89.4      91.15       88.5       98.0      77.89
# skew        0.0  -0.132649   0.162611   0.204164   0.282308   0.313576
# kurtosis   -1.2   -0.60751   0.086901   -0.09749   -1.08858  -0.470723
#
#                  salary
# Mean      277648.648649
# Median         265000.0
# Mode           300000.0
# Q1:25%         240000.0
# Q2:50%         265000.0
# Q3:75%         300000.0
# Q4:100%        390000.0
# IQR             60000.0
# 1.5rule         90000.0
# Lesser         150000.0
# Greater        390000.0
# Min            200000.0
# Max            390000.0
# skew             0.8067
# kurtosis      -0.239837
